# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
supply_clean2 = pd.read_csv(r"D:\data analyst roadmap 1\project guide\supply chain management\supply clean2.csv")

# %%
supply_clean2.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Manufacturing costs Inspection results  \
# ...

# %%
print(supply_clean2.columns)
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs', 'Date', 'month', 'year',
#        'Total Cost / Revenue'],
#       dtype='object')

# %%
supply_clean2.groupby('Product type')['Total Cost / Revenue'].sum()
# Out:
# Product type
# cosmetics     600580.46
# haircare      632896.24
# skincare     1052073.30
# Name: Total Cost / Revenue, dtype: float64

# %%
supply_clean2.groupby('month')['Total Cost / Revenue'].sum()
# Out:
# month
# April       206883.03
# February    798891.15
# January     617448.81
# March       662327.01
# Name: Total Cost / Revenue, dtype: float64

# %%
supply_clean2.groupby('Product type')['Total Cost / Revenue'].sum()
# Out:
# Product type
# cosmetics     600580.46
# haircare      632896.24
# skincare     1052073.30
# Name: Total Cost / Revenue, dtype: float64

# %%
supply_clean2.groupby('Supplier name')['Total Cost / Revenue'].sum()
# Out:
# Supplier name
# Supplier 1    695863.12
# Supplier 2    513672.30
# Supplier 3    406030.50
# Supplier 4    342440.32
# Supplier 5    327543.76
# Name: Total Cost / Revenue, dtype: float64

# %%
import matplotlib.pyplot as plt

supply_clean2.groupby('month')['Total Cost / Revenue'].sum().plot()
plt.title("Monthly Sales Trend")
plt.show()

# %%
supply_clean2.groupby('Product type')['Total Cost / Revenue'].sum().plot(kind='bar')
plt.title("Product Performance")
plt.show()

# %%
supply_clean2['Total Cost / Revenue'].plot(kind='hist')
plt.title("Revenue Distribution")
plt.show()

# %%
supply_clean2.groupby('Location')['Total Cost / Revenue'].sum().plot(kind='pie')
plt.show()
